# %% [markdown]
# # Capstone Project: Create a Customer Segmentation Report for Arvato Financial Services
#
# In this project, you will analyze demographics data for customers of a mail-order sales company in Germany, comparing it against demographics information for the general population. You'll use unsupervised learning techniques to perform customer segmentation, identifying the parts of the population that best describe the core customer base of the company. Then, you'll apply what you've learned on a third dataset with demographics information for targets of a marketing campaign for the company, and use a model to predict which individuals are most likely to convert into becoming customers for the company. The data that you will use has been provided by our partners at Bertelsmann Arvato Analytics, and represents a real-life data science task.
#
# If you completed the first term of this program, you will be familiar with the first part of this project, from the unsupervised learning project. The versions of those two datasets used in this project will include many more features and has not been pre-cleaned. You are also free to choose whatever approach you'd like to analyzing the data rather than follow pre-determined steps. In your work on this project, make sure that you carefully document your steps and decisions, since your main deliverable for this project will be a blog post reporting your findings.

# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans

# magic word for producing visualizations in notebook
# %matplotlib inline

# %% [markdown]
# ## Part 0: Get to Know the Data
#
# There are four data files associated with this project:
#
# - `Udacity_AZDIAS_052018.csv`: Demographics data for the general population of Germany; 891 211 persons (rows) x 366 features (columns).
# - `Udacity_CUSTOMERS_052018.csv`: Demographics data for customers of a mail-order company; 191 652 persons (rows) x 369 features (columns).
# - `Udacity_MAILOUT_052018_TRAIN.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 982 persons (rows) x 367 (columns).
# - `Udacity_MAILOUT_052018_TEST.csv`: Demographics data for individuals who were targets of a marketing campaign; 42 833 persons (rows) x 366 (columns).
#
# Each row of the demographics files represents a single person, but also includes information outside of individuals, including information about their household, building, and neighborhood. Use the information from the first two files to figure out how customers ("CUSTOMERS") are similar to or differ from the general population at large ("AZDIAS"), then use your analysis to make predictions on the other two files ("MAILOUT"), predicting which recipients are most likely to become a customer for the mail-order company.
#
# The "CUSTOMERS" file contains three extra columns ('CUSTOMER_GROUP', 'ONLINE_PURCHASE', and 'PRODUCT_GROUP'), which provide broad information about the customers depicted in the file. The original "MAILOUT" file included one additional column, "RESPONSE", which indicated whether or not each recipient became a customer of the company. For the "TRAIN" subset, this column has been retained, but in the "TEST" subset it has been removed; it is against that withheld column that your final predictions will be assessed in the Kaggle competition.
#
# Otherwise, all of the remaining columns are the same between the three data files. For more information about the columns depicted in the files, you can refer to two Excel spreadsheets provided in the workspace. [One of them](./DIAS Information Levels - Attributes 2017.xlsx) is a top-level list of attributes and descriptions, organized by informational category. [The other](./DIAS Attributes - Values 2017.xlsx) is a detailed mapping of data values for each feature in alphabetical order.
#
# In the below cell, we've provided some initial code to load in the first two datasets. Note for all of the `.csv` data files in this project that they're semicolon (`;`) delimited, so an additional argument in the [`read_csv()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) call has been included to read in the data properly. Also, considering the size of the datasets, it may take some time for them to load completely.
#
# You'll notice when the data is loaded in that a warning message will immediately pop up. Before you really start digging into the modeling and analysis, you're going to need to perform some cleaning. Take some time to browse the structure of the data and look over the informational spreadsheets to understand the data values. Make some decisions on which features to keep, which features to drop, and if any revisions need to be made on data formats. It'll be a good idea to create a function with pre-processing steps, since you'll need to clean all of the datasets before you work with them.

# %%
# load in the data
azdias = pd.read_csv('Udacity_AZDIAS_052018.csv', sep=';')
customers = pd.read_csv('Udacity_CUSTOMERS_052018.csv', sep=';')
# Out:
# /Users/pazilaitipa/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18,19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Check the dataset
azdias.head()
# Out:
#       LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0  910215        -1         NaN       NaN          NaN          NaN
# 1  910220        -1         9.0       0.0          NaN          NaN
# 2  910225        -1         9.0      17.0          NaN          NaN
# 3  910226         2         1.0      13.0          NaN          NaN
# 4  910241        -1         1.0      20.0          NaN          NaN
#
#    ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  ...  \
# 0          NaN          NaN                   NaN                  NaN  ...
# 1          NaN          NaN                  21.0                 11.0  ...
# 2          NaN          NaN                  17.0                 10.0  ...
# 3          NaN          NaN                  13.0                  1.0  ...
# 4          NaN          NaN                  14.0                  3.0  ...
#
#    VHN  VK_DHT4A  VK_DISTANZ  VK_ZG11  W_KEIT_KIND_HH  WOHNDAUER_2008  \
# 0  NaN       NaN         NaN      NaN             NaN             NaN
# 1  4.0       8.0        11.0     10.0             3.0             9.0
# 2  2.0       9.0         9.0      6.0             3.0             9.0
# 3  0.0       7.0        10.0     11.0             NaN             9.0
# 4  2.0       3.0         5.0      4.0             2.0             9.0
#
#    WOHNLAGE ZABEOTYP ANREDE_KZ ALTERSKATEGORIE_GROB
# 0       NaN        3         1                    2
# 1       4.0        5         2                    1
# 2       2.0        5         2                    3
# 3       7.0        3         2                    4
# 4       3.0        4         1                    3
#
# [5 rows x 366 columns]

# %%
azdias.shape
# Out:
# (891221, 366)

# %%
# Check the dataset
customers.head()
# Out:
#       LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0    9626         2         1.0      10.0          NaN          NaN
# 1    9628        -1         9.0      11.0          NaN          NaN
# 2  143872        -1         1.0       6.0          NaN          NaN
# 3  143873         1         1.0       8.0          NaN          NaN
# 4  143874        -1         1.0      20.0          NaN          NaN
#
#    ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  ...  \
# 0          NaN          NaN                  10.0                  1.0  ...
# 1          NaN          NaN                   NaN                  NaN  ...
# 2          NaN          NaN                   0.0                  1.0  ...
# 3          NaN          NaN                   8.0                  0.0  ...
# 4          NaN          NaN                  14.0                  7.0  ...
#
#    VK_ZG11  W_KEIT_KIND_HH  WOHNDAUER_2008  WOHNLAGE  ZABEOTYP  \
# 0      2.0             6.0             9.0       7.0         3
# 1      3.0             0.0             9.0       NaN         3
# 2     11.0             6.0             9.0       2.0         3
# 3      2.0             NaN             9.0       7.0         1
# 4      4.0             2.0             9.0       3.0         1
#
#        PRODUCT_GROUP  CUSTOMER_GROUP ONLINE_PURCHASE ANREDE_KZ  \
# 0  COSMETIC_AND_FOOD     MULTI_BUYER               0         1
# 1               FOOD    SINGLE_BUYER               0         1
# 2  COSMETIC_AND_FOOD     MULTI_BUYER               0         2
# 3           COSMETIC     MULTI_BUYER               0         1
# 4               FOOD     MULTI_BUYER               0         1
#
#   ALTERSKATEGORIE_GROB
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    3
#
# [5 rows x 369 columns]

# %%
customers.shape
# Out:
# (191652, 369)

# %% [markdown]
# ##  Dealing with missing Values

# %% [markdown]
# We can see that some columns contain many NaN values in both data sets, so it's better to check and deal with the NaN values in the datasets first. However, according to the information about the attributes and related values provided in the spreadsheets, some of the coddings are representing the unknown values for the respective attributes. Therefore, I will map the unknown values for each attributes and replace them with np.nan before analysing the nan values.

# %%
# Check the two Excel files that dipcict more information about the columns of the demographic datasets
df_val = pd.read_excel('DIAS Attributes - Values 2017.xlsx')
df_atr = pd.read_excel('DIAS Information Levels - Attributes 2017.xlsx')

# %%
del df_atr['Unnamed: 0']
df_atr.head()
# Out:
#   Information level             Attribute  \
# 0               NaN              AGER_TYP
# 1            Person  ALTERSKATEGORIE_GROB
# 2               NaN             ANREDE_KZ
# 3               NaN         CJT_GESAMTTYP
# 4               NaN     FINANZ_MINIMALIST
#
#                                          Description  \
# 0                                 best-ager typology
# 1                      age through prename analysis
# 2                                             gender
# 3  Customer-Journey-Typology relating to the pref...
# 4         financial typology: low financial interest
#
#                                     Additional notes
# 0  in cooperation with Kantar TNS; the informatio...
# 1  modelled on millions of first name-age-referen...
# 2                                                NaN
# 3  relating to the preferred information, marketi...
# 4  Gfk-Typology based on a representative househo...

# %%
del df_val['Unnamed: 0']
df_val.head()
# Out:
#   Attribute         Description Value                     Meaning
# 0  AGER_TYP  best-ager typology    -1                     unknown
# 1       NaN                 NaN     0  no classification possible
# 2       NaN                 NaN     1             passive elderly
# 3       NaN                 NaN     2            cultural elderly
# 4       NaN                 NaN     3   experience-driven elderly

# %%
# propagate non-null values forward 
df_val = df_val.fillna(method='ffill')
df_val.head()
# Out:
#   Attribute         Description Value                     Meaning
# 0  AGER_TYP  best-ager typology    -1                     unknown
# 1  AGER_TYP  best-ager typology     0  no classification possible
# 2  AGER_TYP  best-ager typology     1             passive elderly
# 3  AGER_TYP  best-ager typology     2            cultural elderly
# 4  AGER_TYP  best-ager typology     3   experience-driven elderly

# %%
# Codes for unknomn values 

df_val_unknown = df_val[df_val['Meaning'].isin(["unknown", "unknown / no main age detectable", "no transaction known", "no transactions known"])][['Attribute', 'Value']]

# Mapping unknown codes of each attribute into a dictionary
unknowns = {}
for i, j in df_val_unknown.values:
    if type(j) is int:
         unknowns[i] = [j]
    else:
        unknowns[i] = [int(x) for x in j.split(',')]

# %%
unknowns
# Out:
# {'AGER_TYP': [-1],
#  'ALTERSKATEGORIE_GROB': [-1, 0],
#  'ALTER_HH': [0],
#  'ANREDE_KZ': [-1, 0],
#  'BALLRAUM': [-1],
#  'BIP_FLAG': [-1],
#  'CAMEO_DEUG_2015': [-1],
#  'CAMEO_DEUINTL_2015': [-1],
#  'CJT_GESAMTTYP': [0],
#  'D19_BANKEN_ANZ_12': [0],
#  'D19_BANKEN_ANZ_24': [0],
#  'D19_BANKEN_DATUM': [10],
#  'D19_BANKEN_DIREKT_RZ': [0],
#  'D19_BANKEN_GROSS_RZ': [0],
#  'D19_BANKEN_LOKAL_RZ': [0],
#  'D19_BANKEN_OFFLINE_DATUM': [10],
#  'D19_BANKEN_ONLINE_DATUM': [10],
#  'D19_BANKEN_REST_RZ': [0],
#  'D19_BEKLEIDUNG_GEH_RZ': [0],
#  'D19_BEKLEIDUNG_REST_RZ': [0],
#  'D19_BILDUNG_RZ': [0],
#  'D19_BIO_OEKO_RZ': [0],
#  'D19_BUCH_RZ': [0],
#  'D19_DIGIT_SERV_RZ': [0],
#  'D19_DROGERIEARTIKEL_RZ': [0],
#  'D19_ENERGIE_RZ': [0],
#  'D19_FREIZEIT_RZ': [0],
#  'D19_GARTEN_RZ': [0],
#  'D19_GESAMT_ANZ_12': [0],
#  'D19_GESAMT_ANZ_24': [0],
#  'D19_GESAMT_DATUM': [10],
#  'D19_GESAMT_OFFLINE_DATUM': [10],
#  'D19_GESAMT_ONLINE_DATUM': [10],
#  'D19_HANDWERK_RZ': [0],
#  'D19_HAUS_DEKO_RZ': [0],
#  'D19_KINDERARTIKEL_RZ': [0],
#  'D19_KK_KUNDENTYP': [-1],
#  'D19_KOSMETIK_RZ': [0],
#  'D19_LEBENSMITTEL_RZ': [0],
#  'D19_LOTTO_RZ': [0],
#  'D19_NAHRUNGSERGAENZUNG_RZ': [0],
#  'D19_RATGEBER_RZ': [0],
#  'D19_REISEN_RZ': [0],
#  'D19_SAMMELARTIKEL_RZ': [0],
#  'D19_SCHUHE_RZ': [0],
#  'D19_SONSTIGE_RZ': [0],
#  'D19_TECHNIK_RZ': [0],
#  'D19_TELKO_ANZ_12': [0],
#  'D19_TELKO_ANZ_24': [0],
#  'D19_TELKO_DATUM': [10],
#  'D19_TELKO_MOBILE_RZ': [0],
#  'D19_TELKO_OFFLINE_DATUM': [10],
#  'D19_TELKO_ONLINE_DATUM': [10],
#  'D19_TELKO_REST_RZ': [0],
#  'D19_TIERARTIKEL_RZ': [0],
#  'D19_VERSAND_ANZ_12': [0],
#  'D19_VERSAND_ANZ_24': [0],
#  'D19_VERSAND_DATUM': [10],
#  'D19_VERSAND_OFFLINE_DATUM': [10],
#  'D19_VERSAND_ONLINE_DATUM': [10],
#  'D19_VERSAND_REST_RZ': [0],
#  'D19_VERSICHERUNGEN_RZ': [0],
#  'D19_VERSI_ANZ_12': [0],
#  'D19_VERSI_ANZ_24': [0],
#  'D19_VOLLSORTIMENT_RZ': [0],
#  'D19_WEIN_FEINKOST_RZ': [0],
#  'EWDICHTE': [-1],
#  'FINANZTYP': [-1],
#  'FINANZ_ANLEGER': [-1],
#  'FINANZ_HAUSBAUER': [-1],
#  'FINANZ_MINIMALIST': [-1],
#  'FINANZ_SPARER': [-1],
#  'FINANZ_UNAUFFAELLIGER': [-1],
#  'FINANZ_VORSORGER': [-1],
#  'GEBAEUDETYP': [-1, 0],
#  'GEOSCORE_KLS7': [-1, 0],
#  'HAUSHALTSSTRUKTUR': [-1, 0],
#  'HEALTH_TYP': [-1],
#  'HH_EINKOMMEN_SCORE': [-1, 0],
#  'INNENSTADT': [-1],
#  'KBA05_ALTER1': [-1, 9],
#  'KBA05_ALTER2': [-1, 9],
#  'KBA05_ALTER3': [-1, 9],
#  'KBA05_ALTER4': [-1, 9],
#  'KBA05_ANHANG': [-1, 9],
#  'KBA05_ANTG1': [-1],
#  'KBA05_ANTG2': [-1],
#  'KBA05_ANTG3': [-1],
#  'KBA05_ANTG4': [-1],
#  'KBA05_AUTOQUOT': [-1, 9],
#  'KBA05_BAUMAX': [-1, 0],
#  'KBA05_CCM1': [-1, 9],
#  'KBA05_CCM2': [-1, 9],
#  'KBA05_CCM3': [-1, 9],
#  'KBA05_CCM4': [-1, 9],
#  'KBA05_DIESEL': [-1, 9],
#  'KBA05_FRAU': [-1, 9],
#  'KBA05_GBZ': [-1, 0],
#  'KBA05_HERST1': [-1, 9],
#  'KBA05_HERST2': [-1, 9],
#  'KBA05_HERST3': [-1, 9],
#  'KBA05_HERST4': [-1, 9],
#  'KBA05_HERST5': [-1, 9],
#  'KBA05_HERSTTEMP': [-1, 9],
#  'KBA05_KRSAQUOT': [-1, 9],
#  'KBA05_KRSHERST1': [-1, 9],
#  'KBA05_KRSHERST2': [-1, 9],
#  'KBA05_KRSHERST3': [-1, 9],
#  'KBA05_KRSKLEIN': [-1, 9],
#  'KBA05_KRSOBER': [-1, 9],
#  'KBA05_KRSVAN': [-1, 9],
#  'KBA05_KRSZUL': [-1, 9],
#  'KBA05_KW1': [-1, 9],
#  'KBA05_KW2': [-1, 9],
#  'KBA05_KW3': [-1, 9],
#  'KBA05_MAXAH': [-1, 9],
#  'KBA05_MAXBJ': [-1, 9],
#  'KBA05_MAXHERST': [-1, 9],
#  'KBA05_MAXSEG': [-1, 9],
#  'KBA05_MAXVORB': [-1, 9],
#  'KBA05_MOD1': [-1, 9],
#  'KBA05_MOD2': [-1, 9],
#  'KBA05_MOD3': [-1, 9],
#  'KBA05_MOD4': [-1, 9],
#  'KBA05_MOD8': [-1, 9],
#  'KBA05_MODTEMP': [-1, 9],
#  'KBA05_MOTOR': [-1, 9],
#  'KBA05_MOTRAD': [-1, 9],
#  'KBA05_SEG1': [-1, 9],
#  'KBA05_SEG10': [-1, 9],
#  'KBA05_SEG2': [-1, 9],
#  'KBA05_SEG3': [-1, 9],
#  'KBA05_SEG4': [-1, 9],
#  'KBA05_SEG5': [-1, 9],
#  'KBA05_SEG6': [-1, 9],
#  'KBA05_SEG7': [-1, 9],
#  'KBA05_SEG8': [-1, 9],
#  'KBA05_SEG9': [-1, 9],
#  'KBA05_VORB0': [-1, 9],
#  'KBA05_VORB1': [-1, 9],
#  'KBA05_VORB2': [-1, 9],
#  'KBA05_ZUL1': [-1, 9],
#  'KBA05_ZUL2': [-1, 9],
#  'KBA05_ZUL3': [-1, 9],
#  'KBA05_ZUL4': [-1, 9],
#  'KBA13_ALTERHALTER_30': [-1],
#  'KBA13_ALTERHALTER_45': [-1],
#  'KBA13_ALTERHALTER_60': [-1],
#  'KBA13_ALTERHALTER_61': [-1],
#  'KBA13_AUDI': [-1],
#  'KBA13_AUTOQUOTE': [-1],
#  'KBA13_BJ_1999': [-1],
#  'KBA13_BJ_2000': [-1],
#  'KBA13_BJ_2004': [-1],
#  'KBA13_BJ_2006': [-1],
#  'KBA13_BJ_2008': [-1],
#  'KBA13_BJ_2009': [-1],
#  'KBA13_BMW': [-1],
#  'KBA13_CCM_1000': [-1],
#  'KBA13_CCM_1200': [-1],
#  'KBA13_CCM_1400': [-1],
#  'KBA13_CCM_0_1400': [-1],
#  'KBA13_CCM_1500': [-1],
#  'KBA13_CCM_1400_2500': [-1],
#  'KBA13_CCM_1600': [-1],
#  'KBA13_CCM_1800': [-1],
#  'KBA13_CCM_2000': [-1],
#  'KBA13_CCM_2500': [-1],
#  'KBA13_CCM_2501': [-1],
#  'KBA13_CCM_3000': [-1],
#  'KBA13_CCM_3001': [-1],
#  'KBA13_FAB_ASIEN': [-1],
#  'KBA13_FAB_SONSTIGE': [-1],
#  'KBA13_FIAT': [-1],
#  'KBA13_FORD': [-1],
#  'KBA13_HALTER_20': [-1],
#  'KBA13_HALTER_25': [-1],
#  'KBA13_HALTER_30': [-1],
#  'KBA13_HALTER_35': [-1],
#  'KBA13_HALTER_40': [-1],
#  'KBA13_HALTER_45': [-1],
#  'KBA13_HALTER_50': [-1],
#  'KBA13_HALTER_55': [-1],
#  'KBA13_HALTER_60': [-1],
#  'KBA13_HALTER_65': [-1],
#  'KBA13_HALTER_66': [-1],
#  'KBA13_HERST_ASIEN': [-1],
#  'KBA13_HERST_AUDI_VW': [-1],
#  'KBA13_HERST_BMW_BENZ': [-1],
#  'KBA13_HERST_EUROPA': [-1],
#  'KBA13_HERST_FORD_OPEL': [-1],
#  'KBA13_HERST_SONST': [-1],
#  'KBA13_KMH_110': [-1],
#  'KBA13_KMH_140': [-1],
#  'KBA13_KMH_180': [-1],
#  'KBA13_KMH_0_140': [-1],
#  'KBA13_KMH_140_210': [-1],
#  'KBA13_KMH_211': [-1],
#  'KBA13_KMH_250': [-1],
#  'KBA13_KMH_251': [-1],
#  'KBA13_KRSAQUOT': [-1],
#  'KBA13_KRSHERST_AUDI_VW': [-1],
#  'KBA13_KRSHERST_BMW_BENZ': [-1],
#  'KBA13_KRSHERST_FORD_OPEL': [-1],
#  'KBA13_KRSSEG_KLEIN': [-1],
#  'KBA13_KRSSEG_OBER': [-1],
#  'KBA13_KRSSEG_VAN': [-1],
#  'KBA13_KRSZUL_NEU': [-1],
#  'KBA13_KW_30': [-1],
#  'KBA13_KW_40': [-1],
#  'KBA13_KW_50': [-1],
#  'KBA13_KW_60': [-1],
#  'KBA13_KW_0_60': [-1],
#  'KBA13_KW_70': [-1],
#  'KBA13_KW_61_120': [-1],
#  'KBA13_KW_80': [-1],
#  'KBA13_KW_90': [-1],
#  'KBA13_KW_110': [-1],
#  'KBA13_KW_120': [-1],
#  'KBA13_KW_121': [-1],
#  'KBA13_MAZDA': [-1],
#  'KBA13_MERCEDES': [-1],
#  'KBA13_MOTOR': [-1],
#  'KBA13_NISSAN': [-1],
#  'KBA13_OPEL': [-1],
#  'KBA13_PEUGEOT': [-1],
#  'KBA13_RENAULT': [-1],
#  'KBA13_SEG_GELAENDEWAGEN': [-1],
#  'KBA13_SEG_GROSSRAUMVANS': [-1],
#  'KBA13_SEG_KLEINST': [-1],
#  'KBA13_SEG_KLEINWAGEN': [-1],
#  'KBA13_SEG_KOMPAKTKLASSE': [-1],
#  'KBA13_SEG_MINIVANS': [-1],
#  'KBA13_SEG_MINIWAGEN': [-1],
#  'KBA13_SEG_MITTELKLASSE': [-1],
#  'KBA13_SEG_OBEREMITTELKLASSE': [-1],
#  'KBA13_SEG_OBERKLASSE': [-1],
#  'KBA13_SEG_SONSTIGE': [-1],
#  'KBA13_SEG_SPORTWAGEN': [-1],
#  'KBA13_SEG_UTILITIES': [-1],
#  'KBA13_SEG_VAN': [-1],
#  'KBA13_SEG_WOHNMOBILE': [-1],
#  'KBA13_SITZE_4': [-1],
#  'KBA13_SITZE_5': [-1],
#  'KBA13_SITZE_6': [-1],
#  'KBA13_TOYOTA': [-1],
#  'KBA13_VORB_0': [-1],
#  'KBA13_VORB_1': [-1],
#  'KBA13_VORB_1_2': [-1],
#  'KBA13_VORB_2': [-1],
#  'KBA13_VORB_3': [-1],
#  'KBA13_VW': [-1],
#  'KKK': [-1, 0],
#  'NATIONALITAET_KZ': [-1, 0],
#  'ORTSGR_KLS9': [-1],
#  'OST_WEST_KZ': [-1],
#  'PLZ8_ANTG1': [-1],
#  'PLZ8_ANTG2': [-1],
#  'PLZ8_ANTG3': [-1],
#  'PLZ8_ANTG4': [-1],
#  'PLZ8_GBZ': [-1],
#  'PLZ8_HHZ': [-1],
#  'PRAEGENDE_JUGENDJAHRE': [-1, 0],
#  'REGIOTYP': [-1, 0],
#  'RELAT_AB': [-1, 9],
#  'RETOURTYP_BK_S': [0],
#  'SEMIO_DOM': [-1, 9],
#  'SEMIO_ERL': [-1, 9],
#  'SEMIO_FAM': [-1, 9],
#  'SEMIO_KAEM': [-1, 9],
#  'SEMIO_KRIT': [-1, 9],
#  'SEMIO_KULT': [-1, 9],
#  'SEMIO_LUST': [-1, 9],
#  'SEMIO_MAT': [-1, 9],
#  'SEMIO_PFLICHT': [-1, 9],
#  'SEMIO_RAT': [-1, 9],
#  'SEMIO_REL': [-1, 9],
#  'SEMIO_SOZ': [-1, 9],
#  'SEMIO_TRADV': [-1, 9],
#  'SEMIO_VERT': [-1, 9],
#  'SHOPPER_TYP': [-1],
#  'SOHO_FLAG': [-1],
#  'TITEL_KZ': [-1, 0],
#  'VERS_TYP': [-1],
#  'WOHNDAUER_2008': [-1, 0],
#  'WOHNLAGE': [-1],
#  'WACHSTUMSGEBIET_NB': [-1, 0],
#  'W_KEIT_KIND_HH': [-1, 0],
#  'ZABEOTYP': [-1, 9]}

# %%
len(unknowns)
# Out:
# 289

# %%
azdias_cleaning = azdias.copy() # copying the dataset for further processing

# %%
# Checking inconsistent attributes
unknown_keys = []
for col, val in unknowns.items():
    if col not in azdias_cleaning.columns:
        unknown_keys.append(col)
    else:
        continue

# %%
unknown_keys
# Out:
# ['BIP_FLAG',
#  'CAMEO_DEUINTL_2015',
#  'D19_BANKEN_DIREKT_RZ',
#  'D19_BANKEN_GROSS_RZ',
#  'D19_BANKEN_LOKAL_RZ',
#  'D19_BANKEN_REST_RZ',
#  'D19_BEKLEIDUNG_GEH_RZ',
#  'D19_BEKLEIDUNG_REST_RZ',
#  'D19_BILDUNG_RZ',
#  'D19_BIO_OEKO_RZ',
#  'D19_BUCH_RZ',
#  'D19_DIGIT_SERV_RZ',
#  'D19_DROGERIEARTIKEL_RZ',
#  'D19_ENERGIE_RZ',
#  'D19_FREIZEIT_RZ',
#  'D19_GARTEN_RZ',
#  'D19_HANDWERK_RZ',
#  'D19_HAUS_DEKO_RZ',
#  'D19_KINDERARTIKEL_RZ',
#  'D19_KK_KUNDENTYP',
#  'D19_KOSMETIK_RZ',
#  'D19_LEBENSMITTEL_RZ',
#  'D19_LOTTO_RZ',
#  'D19_NAHRUNGSERGAENZUNG_RZ',
#  'D19_RATGEBER_RZ',
#  'D19_REISEN_RZ',
#  'D19_SAMMELARTIKEL_RZ',
#  'D19_SCHUHE_RZ',
#  'D19_SONSTIGE_RZ',
#  'D19_TECHNIK_RZ',
#  'D19_TELKO_MOBILE_RZ',
#  'D19_TELKO_REST_RZ',
#  'D19_TIERARTIKEL_RZ',
#  'D19_VERSAND_REST_RZ',
#  'D19_VERSICHERUNGEN_RZ',
#  'D19_VOLLSORTIMENT_RZ',
#  'D19_WEIN_FEINKOST_RZ',
#  'GEOSCORE_KLS7',
#  'HAUSHALTSSTRUKTUR',
#  'KBA13_CCM_1400_2500',
#  'SOHO_FLAG',
#  'WACHSTUMSGEBIET_NB']

# %% [markdown]
# We can see that there are several attribute names in the spreadsheet that are not in the azdias dataset. However, it is difficult to say whether it is because of the wrong spellig or other reasons. So, I will skip these keys when replacing with nan values.

# %%
# Iterating through each coloumn to replace coded unknown values with np.nan
for col, val in unknowns.items():
    if col in azdias_cleaning.columns:
        azdias_cleaning[col] = azdias_cleaning[col].replace(val, np.nan)
    else:
        continue

# %%
azdias_cleaning.head()
# Out:
#       LNR  AGER_TYP  AKT_DAT_KL  ALTER_HH  ALTER_KIND1  ALTER_KIND2  \
# 0  910215       NaN         NaN       NaN          NaN          NaN
# 1  910220       NaN         9.0       NaN          NaN          NaN
# 2  910225       NaN         9.0      17.0          NaN          NaN
# 3  910226       2.0         1.0      13.0          NaN          NaN
# 4  910241       NaN         1.0      20.0          NaN          NaN
#
#    ALTER_KIND3  ALTER_KIND4  ALTERSKATEGORIE_FEIN  ANZ_HAUSHALTE_AKTIV  ...  \
# 0          NaN          NaN                   NaN                  NaN  ...
# 1          NaN          NaN                  21.0                 11.0  ...
# 2          NaN          NaN                  17.0                 10.0  ...
# 3          NaN          NaN                  13.0                  1.0  ...
# 4          NaN          NaN                  14.0                  3.0  ...
#
#    VHN  VK_DHT4A  VK_DISTANZ  VK_ZG11  W_KEIT_KIND_HH  WOHNDAUER_2008  \
# 0  NaN       NaN         NaN      NaN             NaN             NaN
# 1  4.0       8.0        11.0     10.0             3.0             9.0
# 2  2.0       9.0         9.0      6.0             3.0             9.0
# 3  0.0       7.0        10.0     11.0             NaN             9.0
# 4  2.0       3.0         5.0      4.0             2.0             9.0
#
#    WOHNLAGE ZABEOTYP ANREDE_KZ ALTERSKATEGORIE_GROB
# 0       NaN        3         1                    2
# 1       4.0        5         2                    1
# 2       2.0        5         2                    3
# 3       7.0        3         2                    4
# 4       3.0        4         1                    3
#
# [5 rows x 366 columns]

# %%
# Percentage of missing values for each attribute
perc_miss = azdias_cleaning.isnull().sum() / len(azdias_cleaning)

# %%
# Data frame of missing values in percentage
miss_val_sorted = pd.DataFrame({'perc_miss': perc_miss}).sort_values('perc_miss', ascending=False)
miss_val_sorted.head(20)
# Out:
#                           perc_miss
# ALTER_KIND4                0.998648
# TITEL_KZ                   0.997576
# ALTER_KIND3                0.993077
# D19_TELKO_ONLINE_DATUM     0.990796
# D19_BANKEN_OFFLINE_DATUM   0.977911
# ALTER_KIND2                0.966900
# D19_TELKO_ANZ_12           0.962713
# D19_BANKEN_ANZ_12          0.933252
# D19_TELKO_ANZ_24           0.927052
# D19_VERSI_ANZ_12           0.921532
# D19_TELKO_OFFLINE_DATUM    0.919092
# ALTER_KIND1                0.909048
# D19_BANKEN_ANZ_24          0.891025
# D19_VERSI_ANZ_24           0.871879
# D19_BANKEN_ONLINE_DATUM    0.815715
# D19_BANKEN_DATUM           0.761125
# AGER_TYP                   0.760196
# D19_TELKO_DATUM            0.747063
# EXTSEL992                  0.733996
# D19_VERSAND_ANZ_12         0.715840

# %%
# Histogram of attributes on missing values

n, bins, patches = plt.hist(miss_val_sorted['perc_miss'], facecolor='g', alpha=0.75)

plt.xlabel('Percentage of Missing Values')
plt.ylabel('Counts')
plt.title('Distribution of Attributes in terms of Missing Value')
plt.grid(True)
plt.show()

# %%
# The proportion of attributes in which there are less than 30% values missing
(miss_val_sorted['perc_miss'] < 0.3).mean()
# Out:
# 0.912568306010929

# %% [markdown]
# We can see that there are more than 90% of attributes that have less than 30% missing values. So, I decided to drop the attributes that have more than 30% of values are missing.

# %%
# The list of attributes to drop
col_for_drop = miss_val_sorted[miss_val_sorted['perc_miss'] > 0.3].index.tolist()

# %% [markdown]
# I also droped the column named "LNR" as it is a unique value

# %%
col_for_drop.append('LNR')

# %%
len(col_for_drop)
# Out:
# 33

# %% [markdown]
# Look into the missing data in each row

# %%
perc_miss_row = azdias_cleaning.isnull().sum(axis=1) / azdias_cleaning.shape[1]
# Data frame of missing values in percentage per row
miss_val_sorted_row = pd.DataFrame({'perc_miss_row': perc_miss_row}).sort_values('perc_miss_row', ascending=False)
miss_val_sorted_row.head(20)
# Out:
#         perc_miss_row
# 826869       0.781421
# 537799       0.781421
# 350182       0.778689
# 55664        0.778689
# 373501       0.778689
# 140317       0.773224
# 347712       0.773224
# 57866        0.773224
# 716386       0.773224
# 332962       0.773224
# 5099         0.773224
# 522174       0.773224
# 23667        0.770492
# 629707       0.770492
# 255742       0.770492
# 739769       0.770492
# 763072       0.767760
# 122265       0.767760
# 122258       0.767760
# 495272       0.767760

# %%
# Histogram of rows in terms of missing values

n, bins, patches = plt.hist(miss_val_sorted_row['perc_miss_row'], facecolor='g', alpha=0.75)

plt.xlabel('Percentage of Missing Values')
plt.ylabel('Counts')
plt.title('Distribution of Rows in terms of Missing Value')
plt.grid(True)
plt.show()

# %% [markdown]
# I will drop the rows that more than 70% of the values are missed, and I can still have more than 90% of data available for further analysis.

# %%
(miss_val_sorted_row['perc_miss_row'] > 0.7).mean()
# Out:
# 0.08790300049033853

# %% [markdown]
# ## Dealing with Data Type

# %%
azdias_cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891221 entries, 0 to 891220
# Columns: 366 entries, LNR to ALTERSKATEGORIE_GROB
# dtypes: float64(295), int64(65), object(6)
# memory usage: 2.4+ GB

# %% [markdown]
# In order to conduct dimention redcution and clustering we need all the features to be integer and scaled. So, I will look into the features that are object datatype here.

# %%
# Checking the columns with object datatypes
azdias_object_cols = azdias_cleaning.select_dtypes(include=['object'])
azdias_object_cols.head()
# Out:
#   CAMEO_DEU_2015 CAMEO_DEUG_2015 CAMEO_INTL_2015 D19_LETZTER_KAUF_BRANCHE  \
# 0            NaN             NaN             NaN                      NaN
# 1             8A             8.0            51.0                      NaN
# 2             4C             4.0            24.0            D19_UNBEKANNT
# 3             2A             2.0            12.0            D19_UNBEKANNT
# 4             6B             6.0            43.0               D19_SCHUHE
#
#          EINGEFUEGT_AM OST_WEST_KZ
# 0                  NaN         NaN
# 1  1992-02-10 00:00:00           W
# 2  1992-02-12 00:00:00           W
# 3  1997-04-21 00:00:00           W
# 4  1992-02-12 00:00:00           W

# %%
attr_dict = {}
for col in azdias_object_cols.columns:
    attr_dict[col] = azdias_object_cols[col].value_counts().to_dict()
attr_dict
# Out:
# {'CAMEO_DEU_2015': {'6B': 56672,
#   '8A': 52438,
#   '4C': 47819,
#   '2D': 35074,
#   '3C': 34769,
#   '7A': 34399,
#   '3D': 34307,
#   '8B': 33434,
#   '4A': 33155,
#   '8C': 30993,
#   '9D': 28593,
#   '9B': 27676,
#   '9C': 24987,
#   '7B': 24503,
#   '9A': 20542,
#   '2C': 19422,
#   '8D': 17576,
#   '6E': 16107,
#   '2B': 15486,
#   '5D': 14943,
#   '6C': 14820,
#   '2A': 13249,
#   '5A': 12214,
#   '1D': 11909,
#   '1A': 10850,
#   '3A': 10543,
#   '5B': 10354,
#   '5C': 9935,
#   '7C': 9065,
#   '4B': 9047,
#   '4D': 8570,
#   '3B': 7160,
#   '6A': 6810,
#   '9E': 6379,
#   '6D': 6073,
#   '6F': 5392,
#   '7D': 5333,
#   '4E': 5321,
#   '1E': 5065,
#   '7E': 4633,
#   '1C': 4317,
#   '5F': 4283,
#   '1B': 4071,
#   '5E': 3581,
#   'XX': 373},
#  'CAMEO_DEUG_2015': {'8': 78023,
#   '9': 62578,
#   '6': 61253,
#   '4': 60185,
#   8.0: 56418,
#   '3': 50360,
#   '2': 48276,
#   9.0: 45599,
#   '7': 45021,
#   6.0: 44621,
#   4.0: 43727,
#   3.0: 36419,
#   2.0: 34955,
#   7.0: 32912,
#   '5': 32292,
#   5.0: 23018,
#   '1': 20997,
#   1.0: 15215,
#   'X': 373},
#  'CAMEO_INTL_2015': {'51': 77576,
#   51.0: 56118,
#   '41': 53459,
#   '24': 52882,
#   41.0: 38877,
#   24.0: 38276,
#   '14': 36524,
#   '43': 32730,
#   14.0: 26360,
#   '54': 26207,
#   43.0: 23942,
#   '25': 22837,
#   54.0: 19184,
#   '22': 19173,
#   25.0: 16791,
#   '23': 15653,
#   '13': 15272,
#   '45': 15206,
#   22.0: 13982,
#   '55': 13842,
#   '52': 11836,
#   23.0: 11097,
#   13.0: 11064,
#   '31': 11041,
#   45.0: 10926,
#   '34': 10737,
#   55.0: 10113,
#   '15': 9832,
#   52.0: 8706,
#   '44': 8543,
#   31.0: 7983,
#   34.0: 7787,
#   '12': 7645,
#   15.0: 7142,
#   44.0: 6277,
#   '35': 6090,
#   '32': 6067,
#   '33': 5833,
#   12.0: 5604,
#   32.0: 4287,
#   35.0: 4266,
#   33.0: 4102,
#   'XX': 373},
#  'D19_LETZTER_KAUF_BRANCHE': {'D19_UNBEKANNT': 195338,
#   'D19_VERSICHERUNGEN': 57734,
#   'D19_SONSTIGE': 44722,
#   'D19_VOLLSORTIMENT': 34812,
#   'D19_SCHUHE': 32578,
#   'D19_BUCH_CD': 28754,
#   'D19_VERSAND_REST': 26034,
#   'D19_DROGERIEARTIKEL': 24072,
#   'D19_BANKEN_DIREKT': 23273,
#   'D19_BEKLEIDUNG_REST': 21796,
#   'D19_HAUS_DEKO': 20858,
#   'D19_TELKO_MOBILE': 14447,
#   'D19_ENERGIE': 12084,
#   'D19_TELKO_REST': 11472,
#   'D19_BANKEN_GROSS': 10550,
#   'D19_BEKLEIDUNG_GEH': 10272,
#   'D19_KINDERARTIKEL': 7301,
#   'D19_FREIZEIT': 7257,
#   'D19_TECHNIK': 7002,
#   'D19_LEBENSMITTEL': 6458,
#   'D19_BANKEN_REST': 5247,
#   'D19_RATGEBER': 4931,
#   'D19_NAHRUNGSERGAENZUNG': 4061,
#   'D19_DIGIT_SERV': 3577,
#   'D19_REISEN': 3122,
#   'D19_TIERARTIKEL': 2578,
#   'D19_SAMMELARTIKEL': 2443,
#   'D19_HANDWERK': 2227,
#   'D19_WEIN_FEINKOST': 2164,
#   'D19_GARTEN': 1646,
#   'D19_BANKEN_LOKAL': 1442,
#   'D19_BIO_OEKO': 1232,
#   'D19_BILDUNG': 980,
#   'D19_LOTTO': 839,
#   'D19_KOSMETIK': 805},
#  'EINGEFUEGT_AM': {'1992-02-10 00:00:00': 383738,
#   '1992-02-12 00:00:00': 192264,
#   '1995-02-07 00:00:00': 11181,
#   '2005-12-16 00:00:00': 6291,
#   '2003-11-18 00:00:00': 6050,
#   '1993-03-01 00:00:00': 3204,
#   '2005-04-15 00:00:00': 2343,
#   '2000-05-10 00:00:00': 2327,
#   '2004-04-14 00:00:00': 2290,
#   '2005-08-23 00:00:00': 2078,
#   '1992-02-21 00:00:00': 2074,
#   '1994-02-03 00:00:00': 2032,
#   '1995-10-17 00:00:00': 2022,
#   '1995-10-10 00:00:00': 1944,
#   '1993-09-21 00:00:00': 1819,
#   '1993-09-22 00:00:00': 1484,
#   '1993-04-01 00:00:00': 1298,
#   '1993-04-02 00:00:00': 1292,
#   '1994-12-13 00:00:00': 1171,
#   '1996-03-07 00:00:00': 1151,
#   '1995-10-18 00:00:00': 1139,
#   '1995-07-19 00:00:00': 1117,
#   '2006-01-19 00:00:00': 1116,
#   '2005-04-12 00:00:00': 1093,
#   '2003-11-17 00:00:00': 1051,
#   '1993-10-21 00:00:00': 1046,
#   '1996-05-09 00:00:00': 1021,
#   '1995-08-02 00:00:00': 1005,
#   '1993-09-23 00:00:00': 1005,
#   '1995-08-15 00:00:00': 988,
#   '1994-02-10 00:00:00': 953,
#   '1993-03-23 00:00:00': 889,
#   '1995-09-06 00:00:00': 871,
#   '2004-10-14 00:00:00': 833,
#   '1996-03-29 00:00:00': 816,
#   '1993-11-03 00:00:00': 815,
#   '1996-10-15 00:00:00': 104,
#   '2008-07-02 00:00:00': 103,
#   '1995-09-04 00:00:00': 103,
#   '1995-06-23 00:00:00': 103,
#   '1993-09-14 00:00:00': 103,
#   '1994-09-06 00:00:00': 103,
#   '1996-04-19 00:00:00': 102,
#   '1998-01-20 00:00:00': 102,
#   '2012-08-07 00:00:00': 102,
#   '2006-09-09 00:00:00': 102,
#   '1995-11-23 00:00:00': 102,
#   '1994-09-14 00:00:00': 102,
#   '1994-06-17 00:00:00': 102,
#   '1995-02-02 00:00:00': 102,
#   '1995-10-24 00:00:00': 101,
#   '2012-05-03 00:00:00': 101,
#   '1997-06-21 00:00:00': 100,
#   '1997-05-05 00:00:00': 100,
#   '1997-07-03 00:00:00': 99,
#   '1994-07-21 00:00:00': 99,
#   '2010-05-05 00:00:00': 99,
#   '1996-05-02 00:00:00': 99,
#   '1997-12-18 00:00:00': 99,
#   '1996-10-08 00:00:00': 98,
#   '1993-12-08 00:00:00': 97,
#   '1997-03-20 00:00:00': 97,
#   '1994-11-21 00:00:00': 97,
#   '1997-09-29 00:00:00': 97,
#   '1994-05-06 00:00:00': 97,
#   '2008-01-11 00:00:00': 97,
#   '1994-01-20 00:00:00': 97,
#   '1995-07-12 00:00:00': 96,
#   '1997-07-10 00:00:00': 96,
#   '1996-03-20 00:00:00': 96,
#   '1994-05-18 00:00:00': 96,
#   '1996-08-15 00:00:00': 96,
#   '1994-12-15 00:00:00': 96,
#   '1995-03-14 00:00:00': 95,
#   '1993-04-15 00:00:00': 95,
#   '1995-12-29 00:00:00': 94,
#   '2009-08-07 00:00:00': 94,
#   '2000-06-29 00:00:00': 94,
#   '1998-02-26 00:00:00': 93,
#   '2011-01-04 00:00:00': 93,
#   '1996-08-16 00:00:00': 93,
#   '1996-01-12 00:00:00': 93,
#   '1997-08-18 00:00:00': 93,
#   '1995-03-02 00:00:00': 93,
#   '1995-02-13 00:00:00': 93,
#   '1996-04-24 00:00:00': 92,
#   '1997-05-03 00:00:00': 92,
#   '1995-03-20 00:00:00': 91,
#   '1996-04-10 00:00:00': 91,
#   '1997-01-02 00:00:00': 91,
#   '1995-01-10 00:00:00': 90,
#   '1997-03-03 00:00:00': 90,
#   '1997-01-09 00:00:00': 90,
#   '1994-01-04 00:00:00': 90,
#   '2006-02-16 00:00:00': 90,
#   '1998-02-18 00:00:00': 90,
#   '1994-07-11 00:00:00': 90,
#   '1997-04-08 00:00:00': 89,
#   '1994-12-20 00:00:00': 89,
#   '2005-12-30 00:00:00': 89,
#   '2008-02-18 00:00:00': 89,
#   '1997-02-20 00:00:00': 89,
#   '1997-09-03 00:00:00': 89,
#   '1995-08-01 00:00:00': 88,
#   '1995-11-13 00:00:00': 88,
#   '1997-01-31 00:00:00': 88,
#   '2007-11-28 00:00:00': 88,
#   '1995-11-10 00:00:00': 88,
#   '1995-10-13 00:00:00': 88,
#   '1997-07-18 00:00:00': 88,
#   '1997-10-02 00:00:00': 87,
#   '1995-06-06 00:00:00': 87,
#   '1995-02-24 00:00:00': 87,
#   '1998-01-12 00:00:00': 87,
#   '1996-12-27 00:00:00': 87,
#   '1996-06-26 00:00:00': 87,
#   '1996-04-22 00:00:00': 86,
#   '1993-03-31 00:00:00': 86,
#   '1997-11-10 00:00:00': 86,
#   '1995-07-31 00:00:00': 86,
#   '1997-07-01 00:00:00': 86,
#   '1997-08-26 00:00:00': 86,
#   '1994-04-06 00:00:00': 86,
#   '1995-07-28 00:00:00': 85,
#   '1995-03-30 00:00:00': 85,
#   '1997-06-28 00:00:00': 85,
#   '1997-03-14 00:00:00': 85,
#   '1996-06-24 00:00:00': 85,
#   '1996-11-16 00:00:00': 84,
#   '1997-09-01 00:00:00': 84,
#   '1997-08-25 00:00:00': 84,
#   '1997-04-17 00:00:00': 84,
#   '1997-01-14 00:00:00': 84,
#   '1995-06-08 00:00:00': 84,
#   '1994-04-05 00:00:00': 83,
#   '1993-04-03 00:00:00': 83,
#   '1997-04-14 00:00:00': 83,
#   '1995-02-10 00:00:00': 83,
#   '1994-08-09 00:00:00': 83,
#   '1997-08-20 00:00:00': 83,
#   '1996-07-03 00:00:00': 82,
#   '1997-01-29 00:00:00': 82,
#   '2009-12-08 00:00:00': 82,
#   '1993-04-14 00:00:00': 81,
#   '1993-05-28 00:00:00': 81,
#   '1997-07-02 00:00:00': 81,
#   '1995-07-26 00:00:00': 81,
#   '1996-07-24 00:00:00': 80,
#   '1997-01-30 00:00:00': 80,
#   '1994-09-09 00:00:00': 80,
#   '1997-10-10 00:00:00': 80,
#   '1995-07-13 00:00:00': 79,
#   '1997-03-07 00:00:00': 79,
#   '2010-09-16 00:00:00': 79,
#   '1993-10-05 00:00:00': 79,
#   '1997-08-28 00:00:00': 78,
#   '2006-11-29 00:00:00': 78,
#   '1994-08-31 00:00:00': 78,
#   '1996-02-13 00:00:00': 78,
#   '1997-09-30 00:00:00': 78,
#   '1996-09-20 00:00:00': 77,
#   '2006-09-15 00:00:00': 77,
#   '1996-11-13 00:00:00': 77,
#   '1993-07-02 00:00:00': 77,
#   '1995-09-26 00:00:00': 77,
#   '1996-07-31 00:00:00': 77,
#   '1994-10-26 00:00:00': 77,
#   '1997-06-11 00:00:00': 77,
#   '1994-07-28 00:00:00': 76,
#   '1996-04-16 00:00:00': 76,
#   '1997-05-13 00:00:00': 76,
#   '1997-12-17 00:00:00': 76,
#   '1994-06-20 00:00:00': 76,
#   '1993-12-16 00:00:00': 75,
#   '1997-08-19 00:00:00': 75,
#   '1997-11-04 00:00:00': 75,
#   '1995-09-14 00:00:00': 75,
#   '1993-12-23 00:00:00': 75,
#   '1996-07-09 00:00:00': 74,
#   '1994-08-03 00:00:00': 74,
#   '1994-07-14 00:00:00': 74,
#   '1995-11-27 00:00:00': 74,
#   '2006-10-27 00:00:00': 74,
#   '2006-10-24 00:00:00': 74,
#   '1994-09-08 00:00:00': 73,
#   '1996-06-04 00:00:00': 73,
#   '1995-08-04 00:00:00': 73,
#   '1994-03-18 00:00:00': 73,
#   '1997-12-09 00:00:00': 73,
#   '1996-07-08 00:00:00': 73,
#   '1997-10-21 00:00:00': 73,
#   '1994-01-19 00:00:00': 72,
#   '1995-04-28 00:00:00': 72,
#   '1995-05-22 00:00:00': 72,
#   '1996-04-11 00:00:00': 72,
#   '2009-11-04 00:00:00': 72,
#   '1993-01-28 00:00:00': 71,
#   '1995-01-11 00:00:00': 71,
#   '1997-09-24 00:00:00': 71,
#   '1996-07-06 00:00:00': 71,
#   '1996-08-06 00:00:00': 71,
#   '1996-10-28 00:00:00': 70,
#   '1996-02-02 00:00:00': 70,
#   '1997-09-22 00:00:00': 70,
#   '1995-08-31 00:00:00': 70,
#   '2011-06-08 00:00:00': 70,
#   '1993-07-15 00:00:00': 70,
#   '1996-11-06 00:00:00': 70,
#   '1996-12-05 00:00:00': 69,
#   '1996-04-09 00:00:00': 69,
#   '1996-01-30 00:00:00': 69,
#   '1997-07-14 00:00:00': 69,
#   '2015-09-30 00:00:00': 69,
#   '1993-12-29 00:00:00': 68,
#   '1994-01-25 00:00:00': 68,
#   '1994-06-24 00:00:00': 68,
#   '1995-10-05 00:00:00': 68,
#   '1997-11-11 00:00:00': 68,
#   '1996-03-08 00:00:00': 68,
#   '2012-05-10 00:00:00': 68,
#   '1997-11-24 00:00:00': 68,
#   '1994-08-05 00:00:00': 67,
#   '1995-11-22 00:00:00': 67,
#   '1997-04-24 00:00:00': 67,
#   '1995-10-26 00:00:00': 67,
#   '1992-12-30 00:00:00': 67,
#   '1997-06-27 00:00:00': 67,
#   '1996-12-04 00:00:00': 67,
#   '2008-11-01 00:00:00': 67,
#   '1997-08-27 00:00:00': 66,
#   '1997-11-25 00:00:00': 66,
#   '1993-12-07 00:00:00': 66,
#   '2009-07-10 00:00:00': 65,
#   '1994-09-02 00:00:00': 65,
#   '1997-04-30 00:00:00': 65,
#   '1995-12-06 00:00:00': 65,
#   '2010-11-08 00:00:00': 65,
#   '1993-12-27 00:00:00': 65,
#   '1996-10-04 00:00:00': 65,
#   '1995-10-06 00:00:00': 65,
#   '2009-01-21 00:00:00': 65,
#   '1995-03-16 00:00:00': 64,
#   '1996-11-21 00:00:00': 64,
#   '1993-02-19 00:00:00': 64,
#   '1997-05-14 00:00:00': 64,
#   '2012-01-31 00:00:00': 64,
#   '2008-12-26 00:00:00': 64,
#   '2010-03-30 00:00:00': 63,
#   '1994-01-17 00:00:00': 63,
#   '2011-03-25 00:00:00': 63,
#   '1998-01-05 00:00:00': 63,
#   '1996-07-11 00:00:00': 63,
#   '1996-10-14 00:00:00': 63,
#   '1995-03-22 00:00:00': 63,
#   '2009-12-22 00:00:00': 63,
#   '1994-08-30 00:00:00': 63,
#   '1994-06-21 00:00:00': 63,
#   '1998-04-16 00:00:00': 63,
#   '2009-08-29 00:00:00': 63,
#   '1997-09-18 00:00:00': 62,
#   '2011-01-27 00:00:00': 62,
#   '1997-12-02 00:00:00': 62,
#   '1997-12-01 00:00:00': 62,
#   '2009-12-02 00:00:00': 62,
#   '1995-04-06 00:00:00': 62,
#   '1996-10-03 00:00:00': 61,
#   '2010-02-23 00:00:00': 52,
#   '1997-06-09 00:00:00': 52,
#   '1996-01-17 00:00:00': 52,
#   '1996-05-10 00:00:00': 52,
#   '2013-04-29 00:00:00': 52,
#   '2011-08-24 00:00:00': 52,
#   '1997-04-10 00:00:00': 51,
#   '1996-10-23 00:00:00': 51,
#   '1995-11-17 00:00:00': 51,
#   '1997-09-17 00:00:00': 51,
#   '1998-01-22 00:00:00': 51,
#   '2013-09-05 00:00:00': 51,
#   '1997-06-12 00:00:00': 51,
#   '2002-04-11 00:00:00': 51,
#   '2010-06-26 00:00:00': 51,
#   '1994-11-08 00:00:00': 51,
#   '1995-12-19 00:00:00': 51,
#   '1997-10-07 00:00:00': 51,
#   '1995-09-27 00:00:00': 51,
#   '1993-04-13 00:00:00': 51,
#   '1995-05-12 00:00:00': 51,
#   '1997-11-12 00:00:00': 50,
#   '2007-11-08 00:00:00': 50,
#   '2008-05-11 00:00:00': 50,
#   '2001-09-05 00:00:00': 50,
#   '1995-02-20 00:00:00': 50,
#   '1996-04-30 00:00:00': 50,
#   '1995-11-09 00:00:00': 50,
#   '1996-10-24 00:00:00': 50,
#   '1994-06-09 00:00:00': 50,
#   '1994-11-02 00:00:00': 50,
#   '1998-03-11 00:00:00': 49,
#   '1997-01-10 00:00:00': 49,
#   '1993-09-08 00:00:00': 49,
#   '2011-11-24 00:00:00': 49,
#   '1996-06-05 00:00:00': 49,
#   '1995-02-14 00:00:00': 49,
#   '1996-12-11 00:00:00': 49,
#   '2002-06-24 00:00:00': 49,
#   '1997-06-07 00:00:00': 49,
#   '1996-01-09 00:00:00': 49,
#   '1995-08-03 00:00:00': 49,
#   '2014-10-24 00:00:00': 48,
#   '1996-11-04 00:00:00': 48,
#   '2006-05-18 00:00:00': 48,
#   '2010-08-16 00:00:00': 48,
#   '1995-11-16 00:00:00': 48,
#   '1995-01-09 00:00:00': 48,
#   '1996-06-12 00:00:00': 48,
#   '1998-08-07 00:00:00': 48,
#   '1994-01-12 00:00:00': 48,
#   '1994-12-23 00:00:00': 48,
#   '1999-01-14 00:00:00': 47,
#   '1993-06-04 00:00:00': 47,
#   '1995-08-29 00:00:00': 47,
#   '2000-09-21 00:00:00': 47,
#   '1996-11-28 00:00:00': 46,
#   '2002-03-19 00:00:00': 46,
#   '1994-04-19 00:00:00': 46,
#   '1994-03-03 00:00:00': 46,
#   '1998-11-18 00:00:00': 46,
#   '2009-04-05 00:00:00': 46,
#   '1996-05-21 00:00:00': 46,
#   '1994-06-10 00:00:00': 46,
#   '1996-04-23 00:00:00': 46,
#   '2011-07-04 00:00:00': 46,
#   '2014-11-04 00:00:00': 46,
#   '2009-04-04 00:00:00': 46,
#   '1996-10-18 00:00:00': 46,
#   '1994-05-11 00:00:00': 46,
#   '1997-02-06 00:00:00': 45,
#   '2013-09-02 00:00:00': 45,
#   '2011-06-22 00:00:00': 45,
#   '2013-12-03 00:00:00': 45,
#   '2012-03-29 00:00:00': 45,
#   '2008-05-14 00:00:00': 45,
#   '1995-11-24 00:00:00': 45,
#   '1996-01-03 00:00:00': 45,
#   '1994-11-28 00:00:00': 45,
#   '2013-02-04 00:00:00': 45,
#   '1995-05-23 00:00:00': 45,
#   '1996-12-18 00:00:00': 45,
#   '1998-10-08 00:00:00': 45,
#   '1994-06-22 00:00:00': 45,
#   '1996-07-26 00:00:00': 45,
#   '2011-09-30 00:00:00': 45,
#   '1996-10-02 00:00:00': 45,
#   '1997-10-01 00:00:00': 44,
#   '1996-03-16 00:00:00': 44,
#   '1997-10-22 00:00:00': 44,
#   '1996-01-19 00:00:00': 44,
#   '1997-05-15 00:00:00': 44,
#   '1998-07-20 00:00:00': 44,
#   '1996-02-09 00:00:00': 44,
#   '1996-03-22 00:00:00': 44,
#   '1993-09-03 00:00:00': 44,
#   '2005-12-14 00:00:00': 43,
#   '1993-08-11 00:00:00': 43,
#   '2012-08-24 00:00:00': 43,
#   '1994-07-25 00:00:00': 43,
#   '2014-01-29 00:00:00': 43,
#   '1993-07-01 00:00:00': 43,
#   '1997-07-25 00:00:00': 43,
#   '2011-05-03 00:00:00': 43,
#   '1997-11-22 00:00:00': 43,
#   '1998-08-05 00:00:00': 42,
#   '1997-08-15 00:00:00': 42,
#   '2010-11-15 00:00:00': 42,
#   '1994-04-21 00:00:00': 42,
#   '1996-11-27 00:00:00': 42,
#   '1996-11-07 00:00:00': 42,
#   '1996-06-03 00:00:00': 42,
#   '2011-12-22 00:00:00': 42,
#   '1994-12-19 00:00:00': 42,
#   '2013-02-27 00:00:00': 41,
#   '1998-04-07 00:00:00': 41,
#   '1997-12-13 00:00:00': 41,
#   '1993-02-11 00:00:00': 41,
#   '2008-06-01 00:00:00': 41,
#   '2013-08-22 00:00:00': 41,
#   '1993-12-28 00:00:00': 41,
#   '1997-08-06 00:00:00': 41,
#   '1996-10-21 00:00:00': 41,
#   '2000-08-15 00:00:00': 41,
#   '2007-11-05 00:00:00': 41,
#   '2014-03-18 00:00:00': 41,
#   '2012-02-07 00:00:00': 41,
#   '2011-02-02 00:00:00': 41,
#   '2010-01-06 00:00:00': 41,
#   '2015-10-01 00:00:00': 41,
#   '1994-04-15 00:00:00': 41,
#   '2002-06-19 00:00:00': 41,
#   '2011-03-11 00:00:00': 41,
#   '2002-06-13 00:00:00': 41,
#   '1997-11-29 00:00:00': 41,
#   '2000-07-04 00:00:00': 41,
#   '2011-09-06 00:00:00': 40,
#   '1993-06-08 00:00:00': 40,
#   '1993-05-27 00:00:00': 40,
#   '2013-11-05 00:00:00': 40,
#   '1996-11-08 00:00:00': 40,
#   '1994-06-15 00:00:00': 40,
#   '1997-04-15 00:00:00': 40,
#   '2003-11-13 00:00:00': 40,
#   '1993-09-07 00:00:00': 40,
#   '1996-07-29 00:00:00': 40,
#   '1993-12-03 00:00:00': 40,
#   '2006-02-21 00:00:00': 39,
#   '2008-07-30 00:00:00': 39,
#   '1997-04-16 00:00:00': 39,
#   '1998-05-02 00:00:00': 39,
#   '1998-07-14 00:00:00': 39,
#   '2010-09-04 00:00:00': 39,
#   '2012-11-26 00:00:00': 33,
#   '2015-05-27 00:00:00': 33,
#   '2013-10-02 00:00:00': 33,
#   '1993-05-24 00:00:00': 33,
#   '1996-12-13 00:00:00': 33,
#   '2010-11-30 00:00:00': 33,
#   '2002-04-12 00:00:00': 33,
#   '2014-07-29 00:00:00': 33,
#   '2011-08-02 00:00:00': 33,
#   '1996-04-15 00:00:00': 32,
#   '1997-11-08 00:00:00': 32,
#   '1998-04-20 00:00:00': 32,
#   '2003-11-12 00:00:00': 32,
#   '2001-03-01 00:00:00': 32,
#   '1994-07-18 00:00:00': 32,
#   '1997-08-07 00:00:00': 32,
#   '2013-05-02 00:00:00': 32,
#   '2010-11-09 00:00:00': 32,
#   '1999-03-03 00:00:00': 32,
#   '1998-02-11 00:00:00': 32,
#   '2010-02-12 00:00:00': 32,
#   '2001-10-11 00:00:00': 32,
#   '1997-04-19 00:00:00': 32,
#   '1993-01-25 00:00:00': 32,
#   '1997-11-26 00:00:00': 32,
#   '2012-10-31 00:00:00': 32,
#   '1996-11-11 00:00:00': 32,
#   '1993-03-02 00:00:00': 32,
#   '1997-05-27 00:00:00': 31,
#   '1996-12-14 00:00:00': 31,
#   '2015-02-06 00:00:00': 31,
#   '2011-11-15 00:00:00': 31,
#   '1993-09-06 00:00:00': 31,
#   '1994-01-11 00:00:00': 31,
#   '1995-09-18 00:00:00': 31,
#   '1994-11-10 00:00:00': 31,
#   '1993-09-10 00:00:00': 31,
#   '2002-08-06 00:00:00': 31,
#   '2002-03-07 00:00:00': 31,
#   '1995-05-11 00:00:00': 31,
#   '2015-01-07 00:00:00': 31,
#   '2002-03-18 00:00:00': 31,
#   '2008-08-12 00:00:00': 30,
#   '1997-10-27 00:00:00': 30,
#   '2013-03-27 00:00:00': 30,
#   ...},
#  'OST_WEST_KZ': {'W': 629528, 'O': 168545}}

# %%
len(attr_dict['CAMEO_DEU_2015'])
# Out:
# 45

# %% [markdown]
# I will recode the attribute 'CAMEO_DEU_2015' to an ordinal catagory

# %%
# Mapping the recoding into a dict
recode_CAMEO_DEU_2015 = {}
for val in range (len(df_val[df_val.Attribute == 'CAMEO_DEU_2015']['Value'])):
    recode_CAMEO_DEU_2015[df_val[df_val.Attribute == 'CAMEO_DEU_2015']['Value'].values[val]] = val+1

# %%
# recode the 'XX' with np.nan
recode_CAMEO_DEU_2015['XX'] = np.nan
recode_CAMEO_DEU_2015
# Out:
# {'1A': 1,
#  '1B': 2,
#  '1C': 3,
#  '1D': 4,
#  '1E': 5,
#  '2A': 6,
#  '2B': 7,
#  '2C': 8,
#  '2D': 9,
#  '3A': 10,
#  '3B': 11,
#  '3C': 12,
#  '3D': 13,
#  '4A': 14,
#  '4B': 15,
#  '4C': 16,
#  '4D': 17,
#  '4E': 18,
#  '5A': 19,
#  '5B': 20,
#  '5C': 21,
#  '5D': 22,
#  '5E': 23,
#  '5F': 24,
#  '6A': 25,
#  '6B': 26,
#  '6C': 27,
#  '6D': 28,
#  '6E': 29,
#  '6F': 30,
#  '7A': 31,
#  '7B': 32,
#  '7C': 33,
#  '7D': 34,
#  '7E': 35,
#  '8A': 36,
#  '8B': 37,
#  '8C': 38,
#  '8D': 39,
#  '9A': 40,
#  '9B': 41,
#  '9C': 42,
#  '9D': 43,
#  '9E': 44,
#  'XX': nan}

# %% [markdown]
# I will change the attribute 'CAMEO_DEUG_2015' and 'CAMEO_INTL_2015' to integer

# %%
cols_to_float = ['CAMEO_DEUG_2015', 'CAMEO_INTL_2015']

# %% [markdown]
# I will change the attribute 'OST_WEST_KZ' to binary

# %%
to_binary_OST_WEST_KZ = {'W': 1, 'O': 0}

# %% [markdown]
# I will drop the column D19_LETZTER_KAUF_BRANCHE and EINGEFUEGT_AM

# %%
for i in ['D19_LETZTER_KAUF_BRANCHE', 'EINGEFUEGT_AM']:
    if i not in col_for_drop:
        col_for_drop.append(i)
        print(i)
# Out:
# D19_LETZTER_KAUF_BRANCHE
# EINGEFUEGT_AM

# %% [markdown]
# ## Data Processing
#
# I will build a data processing function to process both datasets for further analysis

# %%
def process_data(df, unknowns=unknowns, recode=recode_CAMEO_DEU_2015, 
                 cols_to_float=cols_to_float, to_binary=to_binary_OST_WEST_KZ, 
                col_for_drop=col_for_drop):
    
    """ 
    Cleaning, imputing and scaling dataset for dimention reduction and clustering 
    
    input: 
    
    df: data frame that we want to be prepared for clustering 
    unknowns: unknown values
    recode: the values for recoding the feature CAMEO_DEU_2015
    cols_to_float: columns to be changed to floats
    to_binary: dictionary for recoding values to binary 
    col_for_drop: columns to be droped
    
    Output:
    df_scalled: the data frame after cleaned, recoded and scalled
    
    """
        
    # Iterating through each coloumn to replace coded unknown values with np.nan
    for col, val in unknowns.items():
        if col in df.columns:
            df[col] = df[col].replace(val, np.nan)
        else:
            continue
            
     # I will recode the attribute 'CAMEO_DEU_2015' to an ordinal catagory
    for key, val in recode.items():
        df['CAMEO_DEU_2015'] = df['CAMEO_DEU_2015'].replace(key, val)
        
    # Change object attributes to float
    df[cols_to_float] = df[cols_to_float].replace(['X', 'XX'], np.nan).astype(float)
    
    # I will change the attribute 'OST_WEST_KZ' to binary
    for key, val in to_binary.items():
        df['OST_WEST_KZ'] = df['OST_WEST_KZ'].replace(key, val)
        
    # Drop the columns with more than 30% values missing
    col_for_remain = list(set(df.columns)-set(col_for_drop))
    df = df.loc[:, col_for_remain]
    
    perc_miss_row = df.isnull().sum(axis=1) / df.shape[1]
    # Data frame of missing values in percentage per row
    miss_val_sorted_row = pd.DataFrame({'perc_miss_row': perc_miss_row}).sort_values('perc_miss_row', ascending=False)
    row_for_drop = miss_val_sorted_row[miss_val_sorted_row['perc_miss_row'] > 0.7].index.tolist()
    df = df.drop(row_for_drop)
    
    # Impute nan values
    imputer = SimpleImputer()
    df_imputed = imputer.fit_transform(df, 'mode')
    df_imputed = pd.DataFrame(df_imputed, columns=df.columns)
    
    # Feature scalling 
    scaler = StandardScaler()
    df_scalled = scaler.fit_transform(df_imputed)
    df_scalled = pd.DataFrame(df_scalled, columns=df_imputed.columns)
    
    return df_scalled

# %%
# cleaning, imputing and scalling the population data azdians 
azdias_ready = process_data(azdias)

# %%
azdias_ready.shape
# Out:
# (817265, 331)

# %%
customers = customers.drop(['CUSTOMER_GROUP', 'ONLINE_PURCHASE', 'PRODUCT_GROUP'], axis=1)

# %%
# cleaning, imputing and scalling the customers data  
customers_ready = process_data(customers)

# %%
customers_ready.shape
# Out:
# (144967, 331)

# %% [markdown]
# ## Part 1: Customer Segmentation Report
#
# The main bulk of your analysis will come in this part of the project. Here, you should use unsupervised learning techniques to describe the relationship between the demographics of the company's existing customers and the general population of Germany. By the end of this part, you should be able to describe parts of the general population that are more likely to be part of the mail-order company's main customer base, and which parts of the general population are less so.

# %% [markdown]
# ## PCA
#
# After cleaning, imputing and scaling the data, I will use princple component analysis to reduce dimention of the original data for unsupervised ML

# %%
# Build a PCA function for reducing dimension.
def pca(n_components, df):
    pca_fit = PCA(n_components).fit(df)
    pca_trans = pca_fit.transform(df)

    return pca_trans, pca_fit

# %%
# using pca function on the azdias_ready dataset
azdias_trans, azdias_fit = pca(None, azdias_ready)

# %%
# plot the cumulative explained variance with all components
plt.figure(figsize=(12, 5))
ax = plt.subplot()
ax.bar(np.arange(len(azdias_fit.explained_variance_ratio_)), azdias_fit.explained_variance_ratio_)
ax.plot(np.cumsum(azdias_fit.explained_variance_ratio_))
 
ax.set_xlabel("Number of Component")
ax.set_ylabel("Cumulative Variance")
plt.title('PCA Plot for all Components')
# Out:
# Text(0.5, 1.0, 'PCA Plot for all Components')

# %% [markdown]
# From the plot above we can see that the comulative explained variance are becoming steady around at the place of 150 components. So I will refit the data with 180 components.

# %%
# Select 180 components and refit the azdias_ready data
azdias_trans_180, azdias_fit_180 = pca(180, azdias_ready)

# %%
# plot the cumulative explained variance with 180 components
plt.figure(figsize=(12, 5))
ax = plt.subplot()
ax.bar(np.arange(len(azdias_fit_180.explained_variance_ratio_)), azdias_fit_180.explained_variance_ratio_)
ax.plot(np.cumsum(azdias_fit_180.explained_variance_ratio_))
 
ax.set_xlabel("Number of Component")
ax.set_ylabel("Cumulative Variance")
plt.title('PCA Plot for 180 Components')
# Out:
# Text(0.5, 1.0, 'PCA Plot for 180 Components')

# %%
variance_explained_180 = sum(azdias_fit_180.explained_variance_ratio_[:180]).round(2)*100
print('variance explained by first 180 components: {}%'.format(variance_explained_180)) # Ratio pf explained variance in first 180 components
# Out:
# variance explained by first 180 components: 91.0%

# %%
azdias_trans_180.shape
# Out:
# (817265, 180)

# %%
# plot the cumulative explained variance with first 5 components
plt.figure(figsize=(12, 5))
ax = plt.subplot()
ax.bar(np.arange(len(azdias_fit_180.explained_variance_ratio_[:3])), azdias_fit_180.explained_variance_ratio_[:3])
ax.plot(np.cumsum(azdias_fit_180.explained_variance_ratio_[:3]))
 
ax.set_xlabel("Number of Component")
ax.set_ylabel("Cumulative Variance")
plt.title('PCA Plot for 180 Components')
# Out:
# Text(0.5, 1.0, 'PCA Plot for 180 Components')

# %% [markdown]
# Let's look at the first 3 components, and find the weights for the first 3 principal component to the respective features

# %%
# Looking in to the weights of the features that has positive impact in first component
azdias_feature_first_component = azdias_fit_180.components_[0]
first_component_positive_top5 = sorted(azdias_feature_first_component, reverse=True)[:5]

top5_positive_features_in_first_component = {}
for i in first_component_positive_top5:
    idx = np.where(azdias_feature_first_component==i)
    features = customers_ready.columns[idx][0]
    top5_positive_features_in_first_component[features] = i
top5_positive_features_in_first_component # the top 5 features with positive weight on the first components
# Out:
# {'PLZ8_ANTG3': 0.1426652726290917,
#  'KBA13_ANTG3': 0.1421138783095939,
#  'KBA13_ANTG4': 0.13873842042609327,
#  'KBA13_BAUMAX': 0.13785900735554676,
#  'CAMEO_DEU_2015': 0.13736831410930458}

# %%
# Looking in to the weights of the features that has negative impact in first component
first_component_negative_top5 = sorted(azdias_feature_first_component, reverse=False)[:5]

top5_negative_features_in_first_component = {}
for i in first_component_negative_top5:
    idx = np.where(azdias_feature_first_component==i)
    features = customers_ready.columns[idx][0]
    top5_negative_features_in_first_component[features] = i
top5_negative_features_in_first_component # the top 5 features with negative weight on the first components
# Out:
# {'MOBI_REGIO': -0.14580588155013927,
#  'PLZ8_ANTG1': -0.14353726671625477,
#  'KBA13_ANTG1': -0.14300280247361508,
#  'LP_STATUS_FEIN': -0.13561201688334013,
#  'KBA05_ANTG1': -0.13545580256537562}

# %%
# Looking in to the weights of the features that has positive impact in second component
azdias_feature_second_component = azdias_fit_180.components_[1]
second_component_positive_top5 = sorted(azdias_feature_second_component, reverse=True)[:5]

top5_positive_features_in_second_component = {}
for i in second_component_positive_top5:
    idx = np.where(azdias_feature_second_component==i)
    features = customers_ready.columns[idx][0]
    top5_positive_features_in_second_component[features] = i
top5_positive_features_in_second_component # the top 5 features with positive weight on the second components
# Out:
# {'KBA13_HERST_BMW_BENZ': 0.18690252507028526,
#  'KBA13_MERCEDES': 0.16000216048165344,
#  'KBA13_SEG_OBEREMITTELKLASSE': 0.15976431521494153,
#  'KBA13_BMW': 0.155500102477993,
#  'KBA13_SITZE_4': 0.14840856103636552}

# %%
# Looking in to the weights of the features that has negative impact in second component
second_component_negative_top5 = sorted(azdias_feature_second_component, reverse=False)[:5]

top5_negative_features_in_second_component = {}
for i in second_component_negative_top5:
    idx = np.where(azdias_feature_second_component==i)
    features = customers_ready.columns[idx][0]
    top5_negative_features_in_second_component[features] = i
top5_negative_features_in_second_component # the top 5 features with negative weight on the second components
# Out:
# {'KBA13_SITZE_5': -0.15300742970048048,
#  'KBA13_SEG_KLEINWAGEN': -0.13426364021203596,
#  'KBA13_KMH_140_210': -0.13391547665088158,
#  'KBA13_HALTER_25': -0.12287543231299962,
#  'KBA13_KMH_180': -0.1223078049534325}

# %%
# Looking in to the weights of the features that has positive impact in third component
azdias_feature_third_component = azdias_fit_180.components_[2]
third_component_positive_top5 = sorted(azdias_feature_third_component, reverse=True)[:5]

top5_positive_features_in_third_component = {}
for i in third_component_positive_top5:
    idx = np.where(azdias_feature_third_component==i)
    features = customers_ready.columns[idx][0]
    top5_positive_features_in_third_component[features] = i
top5_positive_features_in_third_component # the top 5 features with positive weight on the third components
# Out:
# {'PRAEGENDE_JUGENDJAHRE': 0.21789228108001393,
#  'CJT_TYP_1': 0.20893245140273803,
#  'CJT_TYP_2': 0.20563228432589503,
#  'FINANZ_SPARER': 0.2033328728423114,
#  'FINANZ_UNAUFFAELLIGER': 0.18056554480854417}

# %%
# Looking in to the weights of the features that has negative impact in third component
third_component_negative_top5 = sorted(azdias_feature_third_component, reverse=False)[:5]

top5_negative_features_in_third_component = {}
for i in third_component_negative_top5:
    idx = np.where(azdias_feature_third_component==i)
    features = customers_ready.columns[idx][0]
    top5_negative_features_in_third_component[features] = i
top5_negative_features_in_third_component # the top 5 features with negative weight on the third components
# Out:
# {'FINANZ_VORSORGER': -0.19124271695130493,
#  'CJT_TYP_5': -0.18777770548652634,
#  'CJT_TYP_4': -0.1869486997852047,
#  'ALTERSKATEGORIE_GROB': -0.18489438168437258,
#  'CJT_TYP_3': -0.1833209928933272}

# %% [markdown]
# ## Clustering
#
# Lets first apply the K-Means clustering to the generel population

# %%
def kmeans(df, ctr, batch_size):
    '''
    Fit the data with Kmeans clustering
    
    INPUT:
    df: data to fit with kmeans clustering
    ctr - k value
    
    OUTPUT:
    score - SSE score
    '''
    k_means = MiniBatchKMeans(n_clusters=ctr, batch_size=batch_size, random_state=42).fit(df)
    model = k_means.fit(df) # fit the model
    score = np.abs(model.score(df)) # get the SSE score
    
    return score

# %%
# get SSE scores for further visulizasion
scores = []
for ctr in list(range(1,31, 1)):
    scores.append(kmeans(azdias_trans_180, ctr, 40000))

# %%
plt.plot(list(range(1,31, 1)), scores, linestyle='--', marker='o', color='r')
plt.xlabel('K_value')
plt.ylabel('SSE score')
plt.title('SSE score & K values')
# Out:
# Text(0.5, 1.0, 'SSE score & K values')

# %% [markdown]
# According to the elbow method, we can see the SSE score is becomming steady after k is 9. Therefore, 9 clusters are selected.

# %%
plt.plot(list(range(1,31, 1))[:9], scores[:9], linestyle='--', marker='o', color='r')
plt.xlabel('K_value')
plt.ylabel('SSE score')
plt.title('SSE score & K values')
# Out:
# Text(0.5, 1.0, 'SSE score & K values')

# %%
# Fit the azdias cleaned and reduced data with 9 clusters
k_means = KMeans(9)
k_model = k_means.fit(azdias_trans_180)

# %%
# Clusters of general population azdias data
azdias_clusters = k_model.predict(azdias_trans_180)
azdias_clusters
# Out:
# array([0, 0, 1, ..., 0, 2, 7], dtype=int32)

# %%
# Select 180 components and fit the customers_ready data
customers_trans_180, customers_fit_180 = pca(180, customers_ready)

# %%
customers_trans_180.shape
# Out:
# (144967, 180)

# %%
# Clusters of customers data
customers_clusters = k_model.predict(customers_trans_180)
customers_clusters
# Out:
# array([8, 7, 1, ..., 7, 0, 4], dtype=int32)

# %% [markdown]
# ## Compare general poulation with the cutomers clustering

# %%
# Compare the difference of proportion of clusters in general population and customers data

df_gene_clusters = pd.DataFrame(data=azdias_clusters, columns=['cluster'])
prs_gene_clusters = df_gene_clusters.cluster.value_counts() / df_gene_clusters.shape[0]
df_cus_clusters = pd.DataFrame(data=customers_clusters, columns=['cluster'])
prs_cus_clusters = df_cus_clusters.cluster.value_counts() / df_cus_clusters.shape[0]


prs_gene_cus = pd.DataFrame({'general':prs_gene_clusters, 'customers': prs_cus_clusters}) # proportion of clusters in general population and customers data
prs_gene_cus['diff'] = prs_gene_cus.general - prs_gene_cus.customers
prs_gene_cus = prs_gene_cus.reset_index()
prs_gene_cus = prs_gene_cus.sort_values(by= 'diff', ascending=False)
prs_gene_cus
# Out:
#    index   general  customers      diff
# 0      0  0.159104   0.135872  0.023232
# 5      5  0.083478   0.065118  0.018360
# 4      4  0.139670   0.122297  0.017373
# 3      3  0.067546   0.053122  0.014424
# 2      2  0.107138   0.097774  0.009364
# 6      6  0.069518   0.062766  0.006752
# 7      7  0.144027   0.164900 -0.020873
# 8      8  0.088717   0.122021 -0.033304
# 1      1  0.140803   0.176130 -0.035327

# %%
# Plot the proportion of clusters in general population and customers

fig = plt.figure(figsize=(12, 5))

ax = fig.add_subplot()

ax.bar(prs_gene_cus.index-0.15, prs_gene_cus.general, 0.3, label = "General")
ax.bar(prs_gene_cus.index+0.15, prs_gene_cus.customers, 0.3, label = "Customers")

ax.set_xlabel('Clusters')
ax.set_ylabel('Ratio')
ax.set_title('Proportion of clusters in general population and customers')
ax.autoscale(tight=True)
ax.legend()

plt.show()

# %%
# Plot the difference for proportion of clusters in general population and customers

prs_gene_cus.plot.barh(x='index', y='diff', label='Difference', title='Difference for proportion of clusters in general population and customers')


plt.show()

# %% [markdown]
# We can see that the most over-represented cluster for the targeted customers is the cluster 1, and the second one is the cluster 2. I will look into the each customers profile in these two clusters in terms of the original features that have the most impact on the first 3 principle components.

# %%
def customer_in_cluster(idx):
    idx = np.where(customers_clusters==idx) # find the indexis of cutomers within the customer cluster 1
    customers_in_cluster = customers_ready.iloc[idx] # the customers in the cluster 1 with the original features 
    return customers_in_cluster

# %% [markdown]
# Choose the fetures for looking into more deeply in terms of their weight on the top 3 principle components.

# %%
# the top 5 features that have the most impact on the first 3 principle components 
features_for_check = list(set(list(top5_positive_features_in_first_component.keys()) + list(top5_negative_features_in_first_component.keys()) + list(top5_positive_features_in_second_component.keys()) + list(top5_negative_features_in_second_component.keys()) + list(top5_positive_features_in_third_component.keys()) + list(top5_negative_features_in_third_component.keys())))

# %%
print(features_for_check)
print(len(features_for_check)) # there are 30 features to inspect
# Out:
# ['PLZ8_ANTG3', 'KBA13_SITZE_5', 'LP_STATUS_FEIN', 'KBA13_MERCEDES', 'CJT_TYP_4', 'FINANZ_SPARER', 'KBA13_SEG_KLEINWAGEN', 'MOBI_REGIO', 'CJT_TYP_3', 'CJT_TYP_1', 'FINANZ_VORSORGER', 'KBA13_BAUMAX', 'PLZ8_ANTG1', 'KBA13_KMH_140_210', 'KBA05_ANTG1', 'FINANZ_UNAUFFAELLIGER', 'KBA13_BMW', 'CJT_TYP_5', 'KBA13_ANTG1', 'KBA13_ANTG3', 'KBA13_HERST_BMW_BENZ', 'KBA13_KMH_180', 'KBA13_SITZE_4', 'ALTERSKATEGORIE_GROB', 'CAMEO_DEU_2015', 'KBA13_SEG_OBEREMITTELKLASSE', 'PRAEGENDE_JUGENDJAHRE', 'CJT_TYP_2', 'KBA13_ANTG4', 'KBA13_HALTER_25']
# 30

# %%
# Selected features of the customers in cluster 1
customers_first_cluster = customer_in_cluster(1)
top_features_first_cluster = customers_first_cluster[features_for_check]
top_features_first_cluster.head()
# Out:
#     PLZ8_ANTG3  KBA13_SITZE_5  LP_STATUS_FEIN  KBA13_MERCEDES  CJT_TYP_4  \
# 2    -0.448835       0.518776        0.554918        0.638227   0.682772
# 5    -0.448835       0.518776        0.856954       -0.450744   0.682772
# 10   -0.448835       0.518776        0.856954       -0.450744   0.682772
# 32   -0.448835       0.518776        0.856954       -0.450744   0.682772
# 36    0.705526       0.518776        0.554918       -1.539715   0.682772
#
#     FINANZ_SPARER  KBA13_SEG_KLEINWAGEN  MOBI_REGIO  CJT_TYP_3  CJT_TYP_1  \
# 2       -0.518161             -0.797013    0.300308   0.659739  -0.972299
# 5       -0.518161              0.250519    0.300308   0.659739  -0.972299
# 10      -0.518161              0.250519    0.300308   0.659739  -0.972299
# 32      -0.518161             -0.797013   -0.505725   0.659739  -0.972299
# 36      -0.518161              0.250519    0.300308   0.659739  -0.972299
#
#     ...  KBA13_HERST_BMW_BENZ  KBA13_KMH_180  KBA13_SITZE_4  \
# 2   ...              0.546372        0.28197      -0.491482
# 5   ...              0.546372        0.28197      -0.491482
# 10  ...             -0.536918        0.28197      -0.491482
# 32  ...             -0.536918        0.28197      -0.491482
# 36  ...             -1.620208        0.28197      -0.491482
#
#     ALTERSKATEGORIE_GROB  CAMEO_DEU_2015  KBA13_SEG_OBEREMITTELKLASSE  \
# 2               0.661453       -0.244148                    -1.472418
# 5               0.661453       -0.677516                    -0.385953
# 10              0.661453       -0.850864                    -0.385953
# 32              0.661453       -0.504169                     0.700512
# 36              0.661453        0.622590                    -0.385953
#
#     PRAEGENDE_JUGENDJAHRE  CJT_TYP_2  KBA13_ANTG4  KBA13_HALTER_25
# 2               -1.407926  -0.891053    -0.820474         1.509748
# 5               -0.506765  -0.891053    -0.820474        -0.671244
# 10              -0.506765  -0.891053    -0.820474        -0.671244
# 32              -1.107539  -0.891053    -0.820474         0.419252
# 36              -1.407926  -0.891053     0.757510         1.509748
#
# [5 rows x 30 columns]

# %%
# Selected features of the customers in cluster 2
customers_second_cluster = customer_in_cluster(2)
top_features_second_cluster = customers_second_cluster[features_for_check]
top_features_second_cluster.head()
# Out:
#     PLZ8_ANTG3  KBA13_SITZE_5  LP_STATUS_FEIN  KBA13_MERCEDES  CJT_TYP_4  \
# 3     0.705526      -0.549013       -1.861371       -0.450744  -0.232134
# 13    1.859888      -0.549013       -1.861371        1.727198   0.682772
# 17    1.859888      -1.616803       -1.861371        1.727198  -2.976849
# 20    1.859888      -0.549013       -1.861371       -0.450744   0.682772
# 22    1.859888      -1.616803       -1.861371        0.638227  -1.147039
#
#     FINANZ_SPARER  KBA13_SEG_KLEINWAGEN  MOBI_REGIO  CJT_TYP_3  CJT_TYP_1  \
# 3       -0.518161              2.345583   -0.505725  -1.484756   0.942824
# 13      -0.518161             -0.797013   -2.117790   0.659739  -0.014737
# 17       3.073396             -0.797013   -2.117790  -2.557004   1.900386
# 20      -0.518161              1.298051   -0.505725   0.659739  -0.972299
# 22       1.876210             -1.844545   -2.117790  -2.557004   0.942824
#
#     ...  KBA13_HERST_BMW_BENZ  KBA13_KMH_180  KBA13_SITZE_4  \
# 3   ...             -0.536918       1.327800       0.589812
# 13  ...              1.629662       0.281970       0.589812
# 17  ...              1.629662       1.327800       1.671106
# 20  ...              0.546372      -0.763859      -0.491482
# 22  ...              1.629662       0.281970       1.671106
#
#     ALTERSKATEGORIE_GROB  CAMEO_DEU_2015  KBA13_SEG_OBEREMITTELKLASSE  \
# 3              -0.648396        1.142632                    -0.385953
# 13              0.661453        2.096043                     0.700512
# 17             -1.958245        1.576001                     0.700512
# 20              0.661453        0.622590                     1.786977
# 22             -0.648396        2.009370                    -0.385953
#
#     PRAEGENDE_JUGENDJAHRE  CJT_TYP_2  KBA13_ANTG4  KBA13_HALTER_25
# 3                0.694783   1.168970     0.757510        -0.671244
# 13              -1.407926   0.138959     2.335494         0.419252
# 17               2.497105   3.228992     2.335494        -1.761740
# 20              -0.206378  -0.891053     0.757510         0.419252
# 22               0.694783   1.168970     2.335494        -0.671244
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Part 2: Supervised Learning Model
#
# Now that you've found which parts of the population are more likely to be customers of the mail-order company, it's time to build a prediction model. Each of the rows in the "MAILOUT" data files represents an individual that was targeted for a mailout campaign. Ideally, we should be able to use the demographic information from each individual to decide whether or not it will be worth it to include that person in the campaign.
#
# The "MAILOUT" data has been split into two approximately equal parts, each with almost 43 000 data rows. In this part, you can verify your model with the "TRAIN" partition, which includes a column, "RESPONSE", that states whether or not a person became a customer of the company following the campaign. In the next part, you'll need to create predictions on the "TEST" partition, where the "RESPONSE" column has been withheld.

# %%
mailout_train = pd.read_csv('../../data/Term2/capstone/arvato_data/Udacity_MAILOUT_052018_TRAIN.csv', sep=';')

# %% [markdown]
# ## Part 3: Kaggle Competition
#
# Now that you've created a model to predict which individuals are most likely to respond to a mailout campaign, it's time to test that model in competition through Kaggle. If you click on the link [here](http://www.kaggle.com/t/21e6d45d4c574c7fa2d868f0e8c83140), you'll be taken to the competition page where, if you have a Kaggle account, you can enter. If you're one of the top performers, you may have the chance to be contacted by a hiring manager from Arvato or Bertelsmann for an interview!
#
# Your entry to the competition should be a CSV file with two columns. The first column should be a copy of "LNR", which acts as an ID number for each individual in the "TEST" partition. The second column, "RESPONSE", should be some measure of how likely each individual became a customer – this might not be a straightforward probability. As you should have found in Part 2, there is a large output class imbalance, where most individuals did not respond to the mailout. Thus, predicting individual classes and using accuracy does not seem to be an appropriate performance evaluation method. Instead, the competition will be using AUC to evaluate performance. The exact values of the "RESPONSE" column do not matter as much: only that the higher values try to capture as many of the actual customers as possible, early in the ROC curve sweep.

# %%
mailout_test = pd.read_csv('../../data/Term2/capstone/arvato_data/Udacity_MAILOUT_052018_TEST.csv', sep=';')
